# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load experiment results (from MLflow or CSV)
data = pd. read_csv ('experiment_results.csv')
results = pd.DataFrame (data)
results
# Out:
#                               run_id  experiment_id    status  \
# 0   de4024f41fdd4b7d8b5282ccaefea098              3  FINISHED
# 1   5ea576c47b194862a4309e7d0baa2ae5              3  FINISHED
# 2   af487a685aee4a3cb8364475edcec121              3  FINISHED
# 3   1831a737828f48749ec9a4cd93156174              3  FINISHED
# 4   de98ab30eaeb486888bc37c1a01958cc              3  FINISHED
# 5   02aece50eb8346f1b139346de1e16712              3  FINISHED
# 6   f0df4f204bf24dca9778660e52d8954b              3  FINISHED
# 7   5568dbc5f39c4909bf646477ee76fc21              3  FINISHED
# 8   4851ae7a538b4e98b6843917eb7ef346              3  FINISHED
# 9   adb5b770f6d144f281c992435518abb6              3  FINISHED
# 10  22409dfa72b64538b1c6930fd3f3df67              3  FINISHED
# 11  380acf6c24674f2d81fbe3193442f479              3  FINISHED
# 12  06ee3a8bcf7b4d7e922e1ad1b8d4ba2e              3  FINISHED
# 13  0054b117c5794030a7ca6faa5b55c9a1              3  FINISHED
# 14  cfaf604b66b446eca5b178b7c76589b2              3  FINISHED
# 15  33084c1ff8ab443fbb9c7b7eeb9275ed              3  FINISHED
# 16  3e5d623d5f8840a7a05b3e6ca344eee2              3  FINISHED
# 17  9f3e7ab80cf14462bbb158575bd8c0c0              3  FINISHED
# 18  1553a4d7bf0847e99c78dd9a88bd5671              3  FINISHED
#
#                                          artifact_uri  \
# 0   /home/ubuntu/mlruns/3/de4024f41fdd4b7d8b5282cc...
# 1   /home/ubuntu/mlruns/3/5ea576c47b194862a4309e7d...
# 2   /home/ubuntu/mlruns/3/af487a685aee4a3cb8364475...
# 3   /home/ubuntu/mlruns/3/1831a737828f48749ec9a4cd...
# 4   /home/ubuntu/mlruns/3/de98ab30eaeb486888bc37c1...
# 5   /home/ubuntu/mlruns/3/02aece50eb8346f1b139346d...
# 6   /home/ubuntu/mlruns/3/f0df4f204bf24dca9778660e...
# 7   /home/ubuntu/mlruns/3/5568dbc5f39c4909bf646477...
# 8   /home/ubuntu/mlruns/3/4851ae7a538b4e98b6843917...
# 9   /home/ubuntu/mlruns/3/adb5b770f6d144f281c99243...
# 10  /home/ubuntu/mlruns/3/22409dfa72b64538b1c6930f...
# 11  /home/ubuntu/mlruns/3/380acf6c24674f2d81fbe319...
# 12  /home/ubuntu/mlruns/3/06ee3a8bcf7b4d7e922e1ad1...
# 13  /home/ubuntu/mlruns/3/0054b117c5794030a7ca6faa...
# 14  /home/ubuntu/mlruns/3/cfaf604b66b446eca5b178b7...
# 15  /home/ubuntu/mlruns/3/33084c1ff8ab443fbb9c7b7e...
# 16  /home/ubuntu/mlruns/3/3e5d623d5f8840a7a05b3e6c...
# 17  /home/ubuntu/mlruns/3/9f3e7ab80cf14462bbb15857...
# 18  /home/ubuntu/mlruns/3/1553a4d7bf0847e99c78dd9a...
#
#                           start_time                          end_time  \
# 0   2024-12-27 18:36:37.677000+00:00  2024-12-27 18:36:41.863000+00:00
# 1   2024-12-27 11:59:38.228000+00:00  2024-12-27 11:59:41.631000+00:00
# 2   2024-12-27 11:59:34.481000+00:00  2024-12-27 11:59:38.093000+00:00
# 3   2024-12-27 11:59:30.813000+00:00  2024-12-27 11:59:34.350000+00:00
# 4   2024-12-27 11:59:25.958000+00:00  2024-12-27 11:59:30.699000+00:00
# 5   2024-12-27 11:59:21.207000+00:00  2024-12-27 11:59:25.822000+00:00
# 6   2024-12-27 11:59:17.337000+00:00  2024-12-27 11:59:21.068000+00:00
# 7   2024-12-27 11:59:13.577000+00:00  2024-12-27 11:59:17.197000+00:00
# 8   2024-12-27 11:59:08.780000+00:00  2024-12-27 11:59:13.420000+00:00
# 9   2024-12-27 11:59:05.007000+00:00  2024-12-27 11:59:08.646000+00:00
# 10  2024-12-27 11:59:01.124000+00:00  2024-12-27 11:59:04.856000+00:00
# 11  2024-12-27 11:58:56.346000+00:00  2024-12-27 11:59:00.987000+00:00
# 12  2024-12-27 11:58:52.852000+00:00  2024-12-27 11:58:56.246000+00:00
# 13  2024-12-27 11:58:49.124000+00:00  2024-12-27 11:58:52.699000+00:00
# 14  2024-12-27 11:58:45.584000+00:00  2024-12-27 11:58:49.009000+00:00
# 15  2024-12-27 11:58:41.973000+00:00  2024-12-27 11:58:45.460000+00:00
# 16  2024-12-27 11:58:38.443000+00:00  2024-12-27 11:58:41.844000+00:00
# 17  2024-12-27 11:58:34.575000+00:00  2024-12-27 11:58:38.323000+00:00
# 18  2024-12-27 11:58:30.378000+00:00  2024-12-27 11:58:34.436000+00:00
#
#     metrics.false_negatives  metrics.false_positives  \
# 0                         5                        4
# 1                         5                        3
# 2                         4                        3
# 3                         5                        4
# 4                         5                        4
# 5                         6                        5
# 6                         5                        5
# 7                         7                        3
# 8                         7                        3
# 9                         5                        3
# 10                        4                        3
# 11                        5                        2
# 12                        5                        2
# 13                        4                        2
# 14                        3                        2
# 15                        4                        2
# 16                        3                        2
# 17                        6                        2
# 18                        6                        2
#
#     metrics.class_1_precision  metrics.true_positives  ...  tags.os_version  \
# 0                    0.870968                      27  ...       10.0.22631
# 1                    0.900000                      27  ...       10.0.22631
# 2                    0.903226                      28  ...       10.0.22631
# 3                    0.870968                      27  ...       10.0.22631
# 4                    0.870968                      27  ...       10.0.22631
# 5                    0.838710                      26  ...       10.0.22631
# 6                    0.843750                      27  ...       10.0.22631
# 7                    0.892857                      25  ...       10.0.22631
# 8                    0.892857                      25  ...       10.0.22631
# 9                    0.900000                      27  ...       10.0.22631
# 10                   0.903226                      28  ...       10.0.22631
# 11                   0.931034                      27  ...       10.0.22631
# 12                   0.931034                      27  ...       10.0.22631
# 13                   0.933333                      28  ...       10.0.22631
# 14                   0.935484                      29  ...       10.0.22631
# 15                   0.933333                      28  ...       10.0.22631
# 16                   0.935484                      29  ...       10.0.22631
# 17                   0.928571                      26  ...       10.0.22631
# 18                   0.928571                      26  ...       10.0.22631
#
#     tags.mlflow.user                      tags.mlflow.log-model.history  \
# 0      Fateme-Habibi  [{"run_id": "de4024f41fdd4b7d8b5282ccaefea098"...
# 1      Fateme-Habibi  [{"run_id": "5ea576c47b194862a4309e7d0baa2ae5"...
# 2      Fateme-Habibi  [{"run_id": "af487a685aee4a3cb8364475edcec121"...
# 3      Fateme-Habibi  [{"run_id": "1831a737828f48749ec9a4cd93156174"...
# 4      Fateme-Habibi  [{"run_id": "de98ab30eaeb486888bc37c1a01958cc"...
# 5      Fateme-Habibi  [{"run_id": "02aece50eb8346f1b139346de1e16712"...
# 6      Fateme-Habibi  [{"run_id": "f0df4f204bf24dca9778660e52d8954b"...
# 7      Fateme-Habibi  [{"run_id": "5568dbc5f39c4909bf646477ee76fc21"...
# 8      Fateme-Habibi  [{"run_id": "4851ae7a538b4e98b6843917eb7ef346"...
# 9      Fateme-Habibi  [{"run_id": "adb5b770f6d144f281c992435518abb6"...
# 10     Fateme-Habibi  [{"run_id": "22409dfa72b64538b1c6930fd3f3df67"...
# 11     Fateme-Habibi  [{"run_id": "380acf6c24674f2d81fbe3193442f479"...
# 12     Fateme-Habibi  [{"run_id": "06ee3a8bcf7b4d7e922e1ad1b8d4ba2e"...
# 13     Fateme-Habibi  [{"run_id": "0054b117c5794030a7ca6faa5b55c9a1"...
# 14     Fateme-Habibi  [{"run_id": "cfaf604b66b446eca5b178b7c76589b2"...
# 15     Fateme-Habibi  [{"run_id": "33084c1ff8ab443fbb9c7b7eeb9275ed"...
# 16     Fateme-Habibi  [{"run_id": "3e5d623d5f8840a7a05b3e6ca344eee2"...
# 17     Fateme-Habibi  [{"run_id": "9f3e7ab80cf14462bbb158575bd8c0c0"...
# 18     Fateme-Habibi  [{"run_id": "1553a4d7bf0847e99c78dd9a88bd5671"...
#
#     tags.mlflow.source.type  tags.python_version  tags.ram_gb  \
# 0                     LOCAL               3.10.0        15.64
# 1                     LOCAL               3.10.0        15.64
# 2                     LOCAL               3.10.0        15.64
# 3                     LOCAL               3.10.0        15.64
# 4                     LOCAL               3.10.0        15.64
# 5                     LOCAL               3.10.0        15.64
# 6                     LOCAL               3.10.0        15.64
# 7                     LOCAL               3.10.0        15.64
# 8                     LOCAL               3.10.0        15.64
# 9                     LOCAL               3.10.0        15.64
# 10                    LOCAL               3.10.0        15.64
# 11                    LOCAL               3.10.0        15.64
# 12                    LOCAL               3.10.0        15.64
# 13                    LOCAL               3.10.0        15.64
# 14                    LOCAL               3.10.0        15.64
# 15                    LOCAL               3.10.0        15.64
# 16                    LOCAL               3.10.0        15.64
# 17                    LOCAL               3.10.0        15.64
# 18                    LOCAL               3.10.0        15.64
#
#                                        tags.processor   tags.mlflow.runName  \
# 0   Intel64 Family 6 Model 154 Stepping 3, Genuine...           fun-pig-311
# 1   Intel64 Family 6 Model 154 Stepping 3, Genuine...      classy-sloth-425
# 2   Intel64 Family 6 Model 154 Stepping 3, Genuine...        melodic-vole-6
# 3   Intel64 Family 6 Model 154 Stepping 3, Genuine...    abundant-goose-529
# 4   Intel64 Family 6 Model 154 Stepping 3, Genuine...    ambitious-frog-704
# 5   Intel64 Family 6 Model 154 Stepping 3, Genuine...  thoughtful-midge-827
# 6   Intel64 Family 6 Model 154 Stepping 3, Genuine...     unruly-shrimp-975
# 7   Intel64 Family 6 Model 154 Stepping 3, Genuine...   inquisitive-lark-41
# 8   Intel64 Family 6 Model 154 Stepping 3, Genuine...      polite-moose-767
# 9   Intel64 Family 6 Model 154 Stepping 3, Genuine...       kindly-toad-530
# 10  Intel64 Family 6 Model 154 Stepping 3, Genuine...       burly-sheep-328
# 11  Intel64 Family 6 Model 154 Stepping 3, Genuine...   thoughtful-stag-474
# 12  Intel64 Family 6 Model 154 Stepping 3, Genuine...        gaudy-seal-913
# 13  Intel64 Family 6 Model 154 Stepping 3, Genuine...   whimsical-shrew-340
# 14  Intel64 Family 6 Model 154 Stepping 3, Genuine...        upset-colt-515
# 15  Intel64 Family 6 Model 154 Stepping 3, Genuine...  illustrious-hawk-350
# 16  Intel64 Family 6 Model 154 Stepping 3, Genuine...     colorful-grub-455
# 17  Intel64 Family 6 Model 154 Stepping 3, Genuine...      defiant-dove-133
# 18  Intel64 Family 6 Model 154 Stepping 3, Genuine...       stately-pug-104
#
#     tags.registered_model_version  tags.registered_model_name
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# 5                             NaN                         NaN
# 6                             NaN                         NaN
# 7                             NaN                         NaN
# 8                             NaN                         NaN
# 9                             NaN                         NaN
# 10                            NaN                         NaN
# 11                            NaN                         NaN
# 12                            NaN                         NaN
# 13                            NaN                         NaN
# 14                            1.0                    version1
# 15                            NaN                         NaN
# 16                            NaN                         NaN
# 17                            NaN                         NaN
# 18                            NaN                         NaN
#
# [19 rows x 41 columns]

# %%
# Check the columns in the DataFrame
print(results.columns)
# Out:
# Index(['run_id', 'experiment_id', 'status', 'artifact_uri', 'start_time',
#        'end_time', 'metrics.false_negatives', 'metrics.false_positives',
#        'metrics.class_1_precision', 'metrics.true_positives',
#        'metrics.class_0_f1', 'metrics.cv_std', 'metrics.true_negatives',
#        'metrics.class_0_precision', 'metrics.accuracy',
#        'metrics.class_1_support', 'metrics.cv_mean', 'metrics.training_time',
#        'metrics.class_1_f1', 'metrics.class_0_support',
#        'metrics.class_1_recall', 'metrics.class_0_recall', 'params.algorithm',
#        'params.metric', 'params.weights', 'params.n_neighbors',
#        'tags.mlflow.source.git.commit', 'tags.mlflow.source.name',
#        'tags.cpu_count', 'tags.runtime', 'tags.os_name', 'tags.os_version',
#        'tags.mlflow.user', 'tags.mlflow.log-model.history',
#        'tags.mlflow.source.type', 'tags.python_version', 'tags.ram_gb',
#        'tags.processor', 'tags.mlflow.runName',
#        'tags.registered_model_version', 'tags.registered_model_name'],
#       dtype='object')

# %%
# Line plot for accuracy comparison across all runs
results.plot(x='run_id', y='metrics.accuracy', kind='line', figsize=(10, 6), color='b', marker='o')

plt.title('Accuracy Comparison Across All Runs', fontsize=14)
plt.xlabel('Run ID', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.grid(alpha=0.5)
plt.tight_layout()
plt.savefig('Accuracy.png')  # Save as PNG file
plt.show()

# %%
# Histogram for distribution of accuracy across all runs
plt.figure(figsize=(10, 6))
plt.hist(results['metrics.accuracy'], bins=10, color='g', edgecolor='black', alpha=0.7)

plt.title('Distribution of Accuracy Across All Runs', fontsize=14)
plt.xlabel('Accuracy', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(alpha=0.5)
plt.tight_layout()
plt.savefig('Accuracy_distribiuation.png')  # Save as PNG file
plt.show()
