# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load experiment results (from MLflow or CSV)
data = pd. read_csv ('compare_runs.csv')
results = pd.DataFrame (data)
results
# Out:
#                               run_id       experiment_id    status  \
# 0   bec4c319b8b341318595d3c89ac5adb0  332425260785487175  FINISHED
# 1   33d42df32cba415982563e02a2a31db7  332425260785487175  FINISHED
# 2   e500a064950940a99af5b387566056eb  332425260785487175  FINISHED
# 3   54ba761c3f284df0bffa9f9602d6f3af  332425260785487175  FINISHED
# 4   0460ac7879db4ac783143e11624d20df  332425260785487175  FINISHED
# 5   47052ece17744fcbaf0bf5010244a6b0  332425260785487175  FINISHED
# 6   5ed9c9b234d646d8ae40492889afa2cc  332425260785487175  FINISHED
# 7   ed1ed6bae43b454184e4f355928e100f  332425260785487175  FINISHED
# 8   6526ca246f7246bfb8d9f54ee3988e13  332425260785487175  FINISHED
# 9   c794e25ae9af4fa39599015fd32a0f8f  332425260785487175  FINISHED
# 10  2179602da24f491b85d49372b0fe2bd1  332425260785487175  FINISHED
# 11  d20dbcb8fbcb4e788f825f41e76a7eea  332425260785487175  FINISHED
# 12  5fdd811330ef4b2489ee9998e16d99c8  332425260785487175  FINISHED
# 13  dd57730c80e34225a067a08c737b0b47  332425260785487175  FINISHED
# 14  c2ce741dff714760b4dbc78288f76b38  332425260785487175  FINISHED
# 15  209215987faa415bb0e93e50b79d3afd  332425260785487175  FINISHED
# 16  8b46032f63fa4ef38ae2fb309530c251  332425260785487175  FINISHED
# 17  90fc5634d9414b75ba5f99a17f1ba93f  332425260785487175  FINISHED
# 18  239d8b59478b49608ef359379349dc36  332425260785487175  FINISHED
# 19  069d8dbe53fa4c2c9aa7810fc84457b3  332425260785487175  FINISHED
# 20  f4c1835538e547df96b43e793e1cf080  332425260785487175  FINISHED
# 21  3dae0fafb3a043f78c5811d0df1a6bec  332425260785487175  FINISHED
# 22  aa6efb2f6a9e4d15821973b4be0cb8a8  332425260785487175  FINISHED
# 23  fdb68edf0fb44476ba5c9f4fff8ac66a  332425260785487175  FINISHED
# 24  99710b5186294d3087c48c6b9d05d97a  332425260785487175  FINISHED
# 25  fca52d99dc7f462aaec30f853dd8835f  332425260785487175  FINISHED
#
#                                          artifact_uri  \
# 0   mlflow-artifacts:/332425260785487175/bec4c319b...
# 1   mlflow-artifacts:/332425260785487175/33d42df32...
# 2   mlflow-artifacts:/332425260785487175/e500a0649...
# 3   mlflow-artifacts:/332425260785487175/54ba761c3...
# 4   mlflow-artifacts:/332425260785487175/0460ac787...
# 5   mlflow-artifacts:/332425260785487175/47052ece1...
# 6   mlflow-artifacts:/332425260785487175/5ed9c9b23...
# 7   mlflow-artifacts:/332425260785487175/ed1ed6bae...
# 8   mlflow-artifacts:/332425260785487175/6526ca246...
# 9   mlflow-artifacts:/332425260785487175/c794e25ae...
# 10  mlflow-artifacts:/332425260785487175/2179602da...
# 11  mlflow-artifacts:/332425260785487175/d20dbcb8f...
# 12  mlflow-artifacts:/332425260785487175/5fdd81133...
# 13  mlflow-artifacts:/332425260785487175/dd57730c8...
# 14  mlflow-artifacts:/332425260785487175/c2ce741df...
# 15  mlflow-artifacts:/332425260785487175/209215987...
# 16  mlflow-artifacts:/332425260785487175/8b46032f6...
# 17  mlflow-artifacts:/332425260785487175/90fc5634d...
# 18  mlflow-artifacts:/332425260785487175/239d8b594...
# 19  mlflow-artifacts:/332425260785487175/069d8dbe5...
# 20  mlflow-artifacts:/332425260785487175/f4c183553...
# 21  mlflow-artifacts:/332425260785487175/3dae0fafb...
# 22  mlflow-artifacts:/332425260785487175/aa6efb2f6...
# 23  mlflow-artifacts:/332425260785487175/fdb68edf0...
# 24  mlflow-artifacts:/332425260785487175/99710b518...
# 25  mlflow-artifacts:/332425260785487175/fca52d99d...
#
#                           start_time                          end_time  \
# 0   2024-12-29 16:05:38.311000+00:00  2024-12-29 16:05:38.915000+00:00
# 1   2024-12-29 14:43:59.571000+00:00  2024-12-29 14:44:14.628000+00:00
# 2   2024-12-29 14:43:16.041000+00:00  2024-12-29 14:43:33.657000+00:00
# 3   2024-12-29 14:42:28.416000+00:00  2024-12-29 14:42:53.398000+00:00
# 4   2024-12-29 14:41:30.170000+00:00  2024-12-29 14:41:44.814000+00:00
# 5   2024-12-29 14:40:48.186000+00:00  2024-12-29 14:41:07.346000+00:00
# 6   2024-12-29 14:40:13.940000+00:00  2024-12-29 14:40:29.926000+00:00
# 7   2024-12-29 14:39:21.396000+00:00  2024-12-29 14:39:36.999000+00:00
# 8   2024-12-29 14:38:45.451000+00:00  2024-12-29 14:39:00.012000+00:00
# 9   2024-12-29 14:37:55.877000+00:00  2024-12-29 14:38:23.175000+00:00
# 10  2024-12-29 14:34:10.471000+00:00  2024-12-29 14:34:23.128000+00:00
# 11  2024-12-29 14:33:25.586000+00:00  2024-12-29 14:33:46.036000+00:00
# 12  2024-12-29 14:32:26.657000+00:00  2024-12-29 14:32:44.888000+00:00
# 13  2024-12-29 14:31:40.280000+00:00  2024-12-29 14:31:57.250000+00:00
# 14  2024-12-29 14:30:46.689000+00:00  2024-12-29 14:31:02.681000+00:00
# 15  2024-12-29 14:30:01.966000+00:00  2024-12-29 14:30:20.397000+00:00
# 16  2024-12-29 14:29:20.001000+00:00  2024-12-29 14:29:34.390000+00:00
# 17  2024-12-29 14:28:24.532000+00:00  2024-12-29 14:28:40.965000+00:00
# 18  2024-12-29 14:27:36.249000+00:00  2024-12-29 14:27:55.144000+00:00
# 19  2024-12-29 14:26:39.648000+00:00  2024-12-29 14:26:53.734000+00:00
# 20  2024-12-29 14:25:28.289000+00:00  2024-12-29 14:25:47.958000+00:00
# 21  2024-12-29 14:24:52.211000+00:00  2024-12-29 14:25:05.518000+00:00
# 22  2024-12-29 14:23:53.263000+00:00  2024-12-29 14:24:08.989000+00:00
# 23  2024-12-29 14:23:16.224000+00:00  2024-12-29 14:23:31.280000+00:00
# 24  2024-12-29 14:22:27.648000+00:00  2024-12-29 14:22:51.520000+00:00
# 25  2024-12-29 14:20:55.089000+00:00  2024-12-29 14:21:16.074000+00:00
#
#     metrics.class_1_f1  metrics.false_negatives  metrics.true_positives  \
# 0                  NaN                      NaN                     NaN
# 1             0.857143                      5.0                    27.0
# 2             0.793651                      7.0                    25.0
# 3             0.857143                      5.0                    27.0
# 4             0.903226                      4.0                    28.0
# 5             0.786885                      8.0                    24.0
# 6             0.857143                      5.0                    27.0
# 7             0.920635                      3.0                    29.0
# 8             0.774194                      8.0                    24.0
# 9             0.857143                      5.0                    27.0
# 10            0.920635                      3.0                    29.0
# 11            0.800000                      8.0                    24.0
# 12            0.825397                      6.0                    26.0
# 13            0.843750                      5.0                    27.0
# 14            0.806452                      7.0                    25.0
# 15            0.825397                      6.0                    26.0
# 16            0.903226                      4.0                    28.0
# 17            0.786885                      8.0                    24.0
# 18            0.843750                      5.0                    27.0
# 19            0.920635                      3.0                    29.0
# 20            0.781250                      7.0                    25.0
# 21            0.761905                      8.0                    24.0
# 22            0.781250                      7.0                    25.0
# 23            0.833333                      7.0                    25.0
# 24            0.866667                      6.0                    26.0
# 25            0.866667                      6.0                    26.0
#
#     metrics.cv_std  ...   tags.mlflow.runName  tags.mlflow.source.type  \
# 0              NaN  ...    debonair-panda-717                    LOCAL
# 1         0.036804  ...     bright-donkey-163                    LOCAL
# 2         0.010063  ...  orderly-squirrel-391                    LOCAL
# 3         0.036804  ...   unleashed-moose-299                    LOCAL
# 4         0.033356  ...       orderly-owl-665                    LOCAL
# 5         0.018674  ...      abundant-cow-396                    LOCAL
# 6         0.039398  ...       awesome-ram-746                    LOCAL
# 7         0.033154  ...    amusing-turtle-480                    LOCAL
# 8         0.010063  ...     receptive-owl-836                    LOCAL
# 9         0.039398  ...    whimsical-lark-387                    LOCAL
# 10        0.033154  ...      worried-calf-716                    LOCAL
# 11        0.023494  ...  bittersweet-kite-962                    LOCAL
# 12        0.043516  ...       sincere-cat-639                    LOCAL
# 13        0.045479  ...   mercurial-midge-891                    LOCAL
# 14        0.043641  ...      classy-panda-933                    LOCAL
# 15        0.043516  ...      masked-stork-734                    LOCAL
# 16        0.044132  ...         funny-roo-299                    LOCAL
# 17        0.041766  ...     orderly-skink-828                    LOCAL
# 18        0.045479  ...   welcoming-shrew-929                    LOCAL
# 19        0.044132  ...     efficient-yak-455                    LOCAL
# 20        0.043111  ...  agreeable-turtle-147                    LOCAL
# 21        0.035429  ...     bedecked-snail-91                    LOCAL
# 22        0.043111  ...   traveling-perch-793                    LOCAL
# 23        0.012081  ...   persistent-calf-247                    LOCAL
# 24        0.033458  ...       masked-seal-639                    LOCAL
# 25        0.033458  ...        aged-perch-771                    LOCAL
#
#     tags.python_version  tags.ram_gb  tags.processor         tags.runtime  \
# 0                   NaN          NaN             NaN                  NaN
# 1                3.12.3         2.88          x86_64  2024-12-29 14:43:59
# 2                3.12.3         2.88          x86_64  2024-12-29 14:43:16
# 3                3.12.3         2.88          x86_64  2024-12-29 14:42:28
# 4                3.12.3         2.88          x86_64  2024-12-29 14:41:30
# 5                3.12.3         2.88          x86_64  2024-12-29 14:40:48
# 6                3.12.3         2.88          x86_64  2024-12-29 14:40:13
# 7                3.12.3         2.88          x86_64  2024-12-29 14:39:21
# 8                3.12.3         2.88          x86_64  2024-12-29 14:38:45
# 9                3.12.3         2.88          x86_64  2024-12-29 14:37:55
# 10               3.12.3         2.88          x86_64  2024-12-29 14:34:10
# 11               3.12.3         2.88          x86_64  2024-12-29 14:33:25
# 12               3.12.3         2.88          x86_64  2024-12-29 14:32:26
# 13               3.12.3         2.88          x86_64  2024-12-29 14:31:40
# 14               3.12.3         2.88          x86_64  2024-12-29 14:30:46
# 15               3.12.3         2.88          x86_64  2024-12-29 14:30:01
# 16               3.12.3         2.88          x86_64  2024-12-29 14:29:19
# 17               3.12.3         2.88          x86_64  2024-12-29 14:28:24
# 18               3.12.3         2.88          x86_64  2024-12-29 14:27:36
# 19               3.12.3         2.88          x86_64  2024-12-29 14:26:39
# 20               3.12.3         2.88          x86_64  2024-12-29 14:25:28
# 21               3.12.3         2.88          x86_64  2024-12-29 14:24:52
# 22               3.12.3         2.88          x86_64  2024-12-29 14:23:53
# 23               3.12.3         2.88          x86_64  2024-12-29 14:23:16
# 24               3.12.3         2.88          x86_64  2024-12-29 14:22:27
# 25               3.12.3         2.88          x86_64  2024-12-29 14:20:54
#
#                                       tags.os_version  tags.cpu_count  \
# 0                                                 NaN             NaN
# 1   #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 2   #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 3   #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 4   #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 5   #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 6   #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 7   #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 8   #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 9   #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 10  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 11  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 12  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 13  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 14  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 15  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 16  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 17  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 18  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 19  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 20  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 21  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 22  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 23  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 24  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
# 25  #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:0...             3.0
#
#     tags.os_name                      tags.mlflow.log-model.history
# 0            NaN                                                NaN
# 1          Linux  [{"run_id": "33d42df32cba415982563e02a2a31db7"...
# 2          Linux  [{"run_id": "e500a064950940a99af5b387566056eb"...
# 3          Linux  [{"run_id": "54ba761c3f284df0bffa9f9602d6f3af"...
# 4          Linux  [{"run_id": "0460ac7879db4ac783143e11624d20df"...
# 5          Linux  [{"run_id": "47052ece17744fcbaf0bf5010244a6b0"...
# 6          Linux  [{"run_id": "5ed9c9b234d646d8ae40492889afa2cc"...
# 7          Linux  [{"run_id": "ed1ed6bae43b454184e4f355928e100f"...
# 8          Linux  [{"run_id": "6526ca246f7246bfb8d9f54ee3988e13"...
# 9          Linux  [{"run_id": "c794e25ae9af4fa39599015fd32a0f8f"...
# 10         Linux  [{"run_id": "2179602da24f491b85d49372b0fe2bd1"...
# 11         Linux  [{"run_id": "d20dbcb8fbcb4e788f825f41e76a7eea"...
# 12         Linux  [{"run_id": "5fdd811330ef4b2489ee9998e16d99c8"...
# 13         Linux  [{"run_id": "dd57730c80e34225a067a08c737b0b47"...
# 14         Linux  [{"run_id": "c2ce741dff714760b4dbc78288f76b38"...
# 15         Linux  [{"run_id": "209215987faa415bb0e93e50b79d3afd"...
# 16         Linux  [{"run_id": "8b46032f63fa4ef38ae2fb309530c251"...
# 17         Linux  [{"run_id": "90fc5634d9414b75ba5f99a17f1ba93f"...
# 18         Linux  [{"run_id": "239d8b59478b49608ef359379349dc36"...
# 19         Linux  [{"run_id": "069d8dbe53fa4c2c9aa7810fc84457b3"...
# 20         Linux  [{"run_id": "f4c1835538e547df96b43e793e1cf080"...
# 21         Linux  [{"run_id": "3dae0fafb3a043f78c5811d0df1a6bec"...
# 22         Linux  [{"run_id": "aa6efb2f6a9e4d15821973b4be0cb8a8"...
# 23         Linux  [{"run_id": "fdb68edf0fb44476ba5c9f4fff8ac66a"...
# 24         Linux  [{"run_id": "99710b5186294d3087c48c6b9d05d97a"...
# 25         Linux  [{"run_id": "fca52d99dc7f462aaec30f853dd8835f"...
#
# [26 rows x 38 columns]

# %%
# Check the columns in the DataFrame
print(results.columns)
# Out:
# Index(['run_id', 'experiment_id', 'status', 'artifact_uri', 'start_time',
#        'end_time', 'metrics.class_1_f1', 'metrics.false_negatives',
#        'metrics.true_positives', 'metrics.cv_std', 'metrics.class_1_recall',
#        'metrics.true_negatives', 'metrics.false_positives',
#        'metrics.class_0_recall', 'metrics.class_1_precision',
#        'metrics.cv_mean', 'metrics.class_0_f1', 'metrics.class_0_support',
#        'metrics.class_0_precision', 'metrics.training_time',
#        'metrics.class_1_support', 'metrics.accuracy', 'params.algorithm',
#        'params.weights', 'params.metric', 'params.n_neighbors',
#        'tags.mlflow.user', 'tags.mlflow.source.name', 'tags.mlflow.runName',
#        'tags.mlflow.source.type', 'tags.python_version', 'tags.ram_gb',
#        'tags.processor', 'tags.runtime', 'tags.os_version', 'tags.cpu_count',
#        'tags.os_name', 'tags.mlflow.log-model.history'],
#       dtype='object')

# %%
# Line plot for accuracy comparison across all runs
results.plot(x='run_id', y='metrics.accuracy', kind='line', figsize=(10, 6), color='b', marker='o')

plt.title('Accuracy Comparison Across All Runs', fontsize=14)
plt.xlabel('Run ID', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.grid(alpha=0.5)
plt.tight_layout()
plt.savefig('Accuracy.png')  # Save as PNG file
plt.show()

# %%
# Histogram for distribution of accuracy across all runs
plt.figure(figsize=(10, 6))
plt.hist(results['metrics.accuracy'], bins=10, color='g', edgecolor='black', alpha=0.7)

plt.title('Distribution of Accuracy Across All Runs', fontsize=14)
plt.xlabel('Accuracy', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(alpha=0.5)
plt.tight_layout()
plt.savefig('Accuracy_distribiuation.png')  # Save as PNG file
plt.show()
